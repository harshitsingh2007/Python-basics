# %%
import pandas as pd
import numpy as np
import sklearn.preprocessing
from sklearn.preprocessing import StandardScaler
import sklearn.metrics
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# %%
np.random.seed(34)

# %%
sg1=np.random.normal(loc=[20,26],scale=[6,4],size=[100,2])
sg2=np.random.normal(loc=[90,26],scale=[6,4],size=[100,2])
sg3=np.random.normal(loc=[85,79],scale=[5,3],size=[100,2])
sg4=np.random.normal(loc=[29,86],scale=[5,4],size=[100,2])

# %%
data = np.vstack([sg1, sg2, sg3, sg4])
df = pd.DataFrame(data, columns=["Income", "Speed"])

# %%
df
# Out:
#         Income      Speed
# 0    16.141769  26.023427
# 1    20.951951  29.189831
# 2    34.659937  25.295197
# 3     9.423307  21.511453
# 4    11.253697  27.628167
# ..         ...        ...
# 395  25.862870  88.515611
# 396  21.328112  87.431206
# 397  34.268375  87.898428
# 398  32.543111  84.903974
# 399  29.970520  95.670817
#
# [400 rows x 2 columns]

# %%
scaler=StandardScaler()
X_scal
